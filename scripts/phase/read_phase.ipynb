# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('phase_measurement_20260823_173223.npz') 
phi = data['phi']

# %%
data2 = np.load('phase_measurement_20260823_173819.npz') 
phi2 = data2['phi']

# %%
data3 = np.load('phase_measurement_20260823_175041.npz') 
phi3 = data3['phi']

# %%
plt.imshow(phi)

# %%
plt.plot(np.degrees(-phi[1060, :]), label='phi')
#plt.plot(np.degrees(phi2[1060, :]), label='phi')
plt.plot(np.degrees(-phi3[1060, :]), label='phi')
# plt.plot(np.degrees(-phi[1500, :]), label='phi')
# plt.plot(np.degrees(-phi[2000, :]), label='phi')
# plt.xlim([0, 1000])
# plt.ylim([-20, 20])

# %%
y_coord = 1060
x_coord_0 = 1450
x_coord_1 = 1700
delta_x = 20
delta_y = 40

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(phi, cmap='gray')
plt.hlines(y_coord, x_coord_0, x_coord_1, colors='r', linestyles='dashed')
plt.xlim(x_coord_0 - delta_x, x_coord_1 + delta_x)
plt.ylim(y_coord + delta_y, y_coord - delta_y)

plt.subplot(122)
plt.plot(np.degrees(-phi[y_coord, x_coord_0:x_coord_1]), label='phi')
plt.plot(np.degrees(phi2[y_coord, x_coord_0:x_coord_1]), label='phi')
plt.plot(np.degrees(-phi3[y_coord, x_coord_0:x_coord_1]), label='phi')

plt.tight_layout()
