# %%
from instruments.precisionpiezo import PrecisionPiezoCT1P

# %%
serial = "92100065"
piezo = PrecisionPiezoCT1P(serial=serial)
# Out:
# Connected to CT1P  Integrated Piezo Stage (SN 92100065)

# %%
piezo.get_position()
# Out:
# 64.88967558824427

# %%
piezo.move_by(0.2, timeout=60)

# %%
piezo.close()
