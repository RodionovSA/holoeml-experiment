# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load(r"kim_step_calibration_20260823_163504.npz", allow_pickle=True)

# %%
# Baseline

baseline = data["baseline_images"][:,:1000,:1000,0]

plt.figure(figsize=(8, 8))
plt.subplot(2,2, 1)
plt.imshow(baseline[0], cmap="gray")

plt.subplot(2,2, 2)
plt.plot(baseline[6, 500])
plt.plot(baseline[15, 500])
plt.xlim([400, 600])

plt.subplot(2,2, (3, 4))
plt.plot(baseline[:, 500, 500])

plt.tight_layout()

# %%
steps = data["scan_counter"]
scan = data["scan_images"][:,:1000,:1000,0]

# %%
plt.plot(scan[:40, 500, 500], '.-')

# %%
plt.plot(scan[0, 500, :], '.-')
plt.plot(scan[10, 500, :], '.-')
plt.xlim([400, 600])
# Out:
# (400.0, 600.0)
