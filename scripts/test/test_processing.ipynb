# %%
from phase import aia
from pathlib import Path
import instruments.config
from instruments.config import EquipmentConfig

# %%
CONFIG_ROOT = Path(instruments.config.__file__).resolve().parent

# %%
EquipmentConfig.from_yaml(CONFIG_ROOT / "config.yaml")
# Out:
# EquipmentConfig(camera_serial='22500190', focus_serial='27271402', stage_x_serial='27271402', stage_y_serial='27271402', polarizer_serial='55001180', piezo_serial='92100065', powermeter_serial='5003886', spectrometer_serial='SR600410', filterwheel_address='USB0::0x104D::0x1011::7A01020F12162064::RAW', monochromator_port='COM3', monochromator_grating_mode='VIS Grating', camera_vendor='pco', camera_black_level=0, camera_bit_depth='uint16', camera_out_bit_depth='float32', default_focus_max_velocity=0.2, default_focus_acceleration=0.2, default_stage_max_velocity=0.2, default_stage_acceleration=0.2, polarizer_x_position=175, default_polarizer_home_velocity=10, default_polarizer_max_velocity=10, default_polarizer_acceleration=15, filterwheel_timeout=2000, filterwheel_empty_pos=1, longpass_pos=3, black_pos=4)
