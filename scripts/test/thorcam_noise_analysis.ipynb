# %%
import numpy as np
import matplotlib.pyplot as plt

data_read_noise = np.load(r"C:\Users\RODIONSA\Desktop\Codes\holoeml-experiment\thorcam_read_noise_20260709_112500.npz")

# %%
# Read noise data
read_noise = data_read_noise['read_noise']
std_maps = data_read_noise['std_maps']
mean_frames = data_read_noise['mean_frames']
offset_level = data_read_noise['offset_level']
drift_traces = data_read_noise['drift_traces']
gain_range = data_read_noise['gain_range']

# %%
plt.plot(gain_range, read_noise, '.-')
plt.ylabel('read_noise, DN')
plt.xlabel('gain, dB')
plt.grid()
