# %%
import numpy as np
from instruments.inertialpiezo import KIM101, KIM101Axis
from instruments.config import load_equipment

_EQ = load_equipment()
kimpiezo_serial = _EQ.kim_serial
kimpiezo_channel = _EQ.kim_channel

# %%
kim101 = KIM101(kimpiezo_serial)
piezo = KIM101Axis(kim101, kimpiezo_channel)
# Out:
# Connected to KIM101 Motor Controller  (SN 97251973)

# %%
piezo.set_drive_parameters(20, 100, 125)

# %%
piezo.move_by(1)
# Out:
# KIM101 97251973 ch4 moved by 1 steps

# %%
piezo.move_by(-100)
# Out:
# KIM101 97251973 ch4 moved by -100 steps

# %%
kim101.close()
