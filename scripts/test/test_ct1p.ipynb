# %%
from pathlib import Path
import instruments.config
from instruments.precisionpiezo import PrecisionPiezoCT1P
from instruments.config import EquipmentConfig

CONFIG_ROOT = Path(instruments.config.__file__).resolve().parent

cfg = EquipmentConfig.from_yaml(CONFIG_ROOT / "config.yaml")

# %%
piezo = PrecisionPiezoCT1P(cfg.piezo_serial)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 piezo = PrecisionPiezoCT1P(cfg.piezo_serial)
#
# File D:\sergei\holoeml-experiment\instruments\precisionpiezo\precisionpiezo.py:104, in PrecisionPiezoCT1P.__init__(self, serial, kinesis_dir, polling_ms, simulate)
#     102 available = list(DeviceManagerCLI.GetDeviceList(IntegratedPrecisionPiezo.DevicePrefix))
#     103 if serial not in available:
# --> 104     raise RuntimeError(
#     105         f"No CT1P (IntegratedPrecisionPiezo) with serial {serial!r} found. "
#     106         f"Available: {available}"
#     107     )
#     109 self._device = IntegratedPrecisionPiezo.CreateIntegratedPrecisionPiezo(serial)
#     110 self._device.Connect(serial)
#
# RuntimeError: No CT1P (IntegratedPrecisionPiezo) with serial '92100065' found. Available: []

# %%
piezo.close()

# %%
piezo._device.GetTe
