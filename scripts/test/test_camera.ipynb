# %%
from instruments.pythorcam.thorcam import ThorlabsCamera, create_camera_sdk
import numpy as np
import matplotlib.pyplot as plt

SERIAL = "37490"
camerasdk = create_camera_sdk()
camera = ThorlabsCamera(camerasdk, SERIAL)
# Out:
# Camera 37490 is connected

# %%
camera.arm()
image = camera.get_image()
camera.disarm()

# %%
image.shape
# Out:
# (3000, 4096, 1)

# %%
delta

# %%
IMAGE_SHAPE_X0 = 300 
IMAGE_SHAPE_Y0 = 400 
IMAGE_SHAPE_X1 = 3600 
IMAGE_SHAPE_Y1 = 2600 
plt.imshow(image[IMAGE_SHAPE_Y0:IMAGE_SHAPE_Y1,
                                         IMAGE_SHAPE_X0:IMAGE_SHAPE_X1], cmap='gray')
