# %%
from instruments.powermeter import PM400

# %%
pm = PM400(serial="5003886")
# Out:
# Connected to PM400 (SN P5003886)

# %%
pm.get_power_avg(n=10)*1e6
# Out:
# 0.36498670000000005

# %%
pm.set_wavelength(550.0)

# %%
pm.set_auto_range(on=True)

# %%
pm.close()
