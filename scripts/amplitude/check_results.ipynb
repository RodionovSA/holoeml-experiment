# %%
import time
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load(r"C:\Users\RODIONSA\Desktop\Codes\holoeml-experiment\sample_ypol_20260719_151344.npz")
img = data['images'][...,0]

# %%
plt.imshow(img[40,...])
plt.colorbar()
plt.xlim([1500, 2500])
plt.ylim([1000, 2000])
# Out:
# (1000.0, 2000.0)

# %%
plt.plot(img[100,1400])
plt.ylim([4000, 4096])
# Out:
# (4000.0, 4096.0)

# %%
from src.config import Config
from src.control import Control

config = Config.from_yaml("src\config\config.yaml")
control = Control.from_config(config)
# Out:
# Camera 29236 is connected
# Connected to COM4; you can now initialize the Monochromator.
# INFO: monochromator initialized; send `home` to start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 from src.config import Config
#       2 from src.control import Control
#       3
#       4 config = Config.from_yaml("src\config\config.yaml")
# ----> 5 control = Control.from_config(config)
#
# File c:\Users\RODIONSA\Desktop\Codes\holoeml-amp\src\control.py:43, in Control.from_config(cls, config)
#      41 monochromator = MonochromatorControl(port=config.monochromator_port)
#      42 monochromator.initialize_arduino()
# ---> 43 monochromator.home_motor()
#      44 monochromator.select_grating_mode(mode=config.monochromator_grating_mode)
#      46 filterwheel = FilterWheelControl(config.filterwheel_address)
#
# File c:\Users\RODIONSA\Desktop\Codes\holoeml-amp\src\monochromator\mono.py:134, in MonochromatorControl.home_motor(self)
#     132     return
#     133 self._send("home")
# --> 134 outcome, _ = self._wait_for(("OK: homed",), timeout=self.HOMING_TIMEOUT)
#     135 if outcome == "ok":
#     136     self.motor_homed = True
#
# File c:\Users\RODIONSA\Desktop\Codes\holoeml-amp\src\monochromator\mono.py:245, in MonochromatorControl._wait_for(self, ok_prefixes, err_prefixes, timeout)
#     243 deadline = time.monotonic() + (timeout if timeout is not None else self.RESPONSE_TIMEOUT)
#     244 while time.monotonic() < deadline:
# --> 245     line = self.ser.readline().decode(errors="replace").strip()
#     246     if not line:
#     247         continue
#
# File c:\Users\RODIONSA\Desktop\Codes\holoeml-amp\.venv\Lib\site-packages\serial\serialwin32.py:288, in Serial.read(self, size)
#     286 if not read_ok and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
#     287     raise SerialException("ReadFile failed ({!r})".format(ctypes.WinError()))
# --> 288 result_ok = win32.GetOverlappedResult(
#     289     self._port_handle,
#     290     ctypes.byref(self._overlapped_read),
#     291     ctypes.byref(rc),
#     292     True)
#     293 if not result_ok:
#     294     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %%
import pyvisa

ADDR = 'USB0::0x104D::0x1011::7A01020F12162064::RAW'

rm = pyvisa.ResourceManager()
print("resources:", rm.list_resources())   # confirm the wheel is listed

fw = rm.open_resource(ADDR)
fw.timeout = 2000  # ms

print("opened OK:", fw)
print("interface type:", fw.interface_type)
print("manufacturer:", fw.get_visa_attribute(pyvisa.constants.VI_ATTR_MANF_NAME))
print("model:", fw.get_visa_attribute(pyvisa.constants.VI_ATTR_MODEL_NAME))

fw.close()
# Out:
# resources: ('ASRL3::INSTR', 'ASRL4::INSTR')
# opened OK: USBRaw at USB0::0x104D::0x1011::7A01020F12162064::0::RAW
# interface type: 7
# manufacturer: Newport Corporation
# model: Universal Filter Wheel

# %%
from src.filterwheel.filterwheel import FilterWheelControl

ADDR = 'USB0::0x104D::0x1011::7A01020F12162064::RAW'

filter = FilterWheelControl(ADDR)
filter.get_position()
# Out:
# 4

# %%
filter.set_position(3)

# %%
filter.close()

# %%
import serial.tools.list_ports
for port in serial.tools.list_ports.comports():
    print(port.device, port.description)
# Out:
# COM3 Intel(R) Active Management Technology - SOL (COM3)
# COM4 Arduino Uno (COM4)

# %%
# Create camera sdk (ones!)
from src.pythorcam.thorcam import create_camera_sdk
camerasdk = create_camera_sdk()

# %%
# Camera control
from src.pythorcam.thorcam import ThorlabsCamera

serial_number = '29236'
Camera = ThorlabsCamera(camerasdk, serial_number)
Camera.set_settings(exposure_time_us=300000, gain=0, black_level=5, bit_depth=np.uint16, out_bit_depth=np.float32)

Camera.arm()
time.sleep(0.1)

start = time.time()
image = Camera.get_image(num_frames_to_average=1)
end = time.time()

#Continuous_capturing_with_plt(Camera, zoom_value=0.4)

Camera.disarm()
Camera.close()
print(end - start)

plt.imshow(image)
plt.colorbar()
# Out:
# Camera 29236 is connected
# Camera 29236 is disconnected
# 0.3732607364654541

# %%
# Monochromator
from src.monochromator.mono import MonochromatorControl

MonochromatorControl.list_available_ports()
# Out:
# ['COM4', 'COM3']

# %%
monochromator = MonochromatorControl(port='COM4')
# Out:
# Connected to COM4; you can now initialize the Monochromator.

# %%
monochromator.initialize_arduino()
# Out:
# INFO: monochromator initialized; send `home` to start

# %%
monochromator.home_motor()
# Out:
# INFO: homing
# ADC: 282
# OK: homed

# %%
monochromator.select_grating_mode(mode="VIS Grating")
# Out:
# OK: mode VIS

# %%
monochromator.set_wavelength(wavelength=550)
# Out:
# INFO: moving 550.00
# OK: wavelength 550.00

# %%
monochromator.disconnect()
# Out:
# Disconnected from Arduino.

# %%
# Check motors movement 
from pylablib.devices import Thorlabs

mm = 1e-3

focus = Thorlabs.KinesisMotor("27256388", scale='stage')
focus.setup_velocity(max_velocity=0.01*mm)
focus.setup_velocity(acceleration=0.005*mm)
focus.move_by(-0.003*mm) # movement in m
focus.wait_move()
print(focus.get_position()*1000)

focus.close()
# Out:
# 7.806757229477612
